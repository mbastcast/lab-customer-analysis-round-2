# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import os #we will use the function listdir to list files in a folder
import math #to apply absolute value

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

import warnings
warnings.filterwarnings('ignore')

# %%
file1 = pd.read_csv('files_for_lab/csv_files/marketing_customer_analysis.csv')

# %%
file1.head()
# Out:
#    Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    Number of Open Complaints Number of Policies     Policy Type        Policy  \
# 0                        0.0                  9  Corporate Auto  Corporate L3
# 1                        0.0                  1   Personal Auto   Personal L3
# 2                        0.0                  2   Personal Auto   Personal L3
# 3                        0.0                  2  Corporate Auto  Corporate L3
# 4                        NaN                  7   Personal Auto   Personal L2
#
#    Renew Offer Type  Sales Channel  Total Claim Amount  Vehicle Class  \
# 0            Offer3          Agent          292.800000  Four-Door Car
# 1            Offer4    Call Center          744.924331  Four-Door Car
# 2            Offer3    Call Center          480.000000            SUV
# 3            Offer2         Branch          484.013411  Four-Door Car
# 4            Offer1         Branch          707.925645  Four-Door Car
#
#   Vehicle Size Vehicle Type
# 0      Medsize          NaN
# 1      Medsize          NaN
# 2      Medsize            A
# 3      Medsize            A
# 4      Medsize          NaN
#
# [5 rows x 26 columns]

# %%
#Change headers names.

# %%
file1.columns = [column.lower() for column in file1.columns] 
file1.head()
# Out:
#    unnamed: 0 customer       state  customer lifetime value response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    coverage education effective to date employmentstatus gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    number of open complaints number of policies     policy type        policy  \
# 0                        0.0                  9  Corporate Auto  Corporate L3
# 1                        0.0                  1   Personal Auto   Personal L3
# 2                        0.0                  2   Personal Auto   Personal L3
# 3                        0.0                  2  Corporate Auto  Corporate L3
# 4                        NaN                  7   Personal Auto   Personal L2
#
#    renew offer type  sales channel  total claim amount  vehicle class  \
# 0            Offer3          Agent          292.800000  Four-Door Car
# 1            Offer4    Call Center          744.924331  Four-Door Car
# 2            Offer3    Call Center          480.000000            SUV
# 3            Offer2         Branch          484.013411  Four-Door Car
# 4            Offer1         Branch          707.925645  Four-Door Car
#
#   vehicle size vehicle type
# 0      Medsize          NaN
# 1      Medsize          NaN
# 2      Medsize            A
# 3      Medsize            A
# 4      Medsize          NaN
#
# [5 rows x 26 columns]

# %%
file1
# Out:
#       customer       state  customer lifetime value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       education effective to date employmentstatus gender  income  ...  \
# 0       College           2/18/11         Employed      M   48029  ...
# 1       College           1/18/11       Unemployed      F       0  ...
# 2      Bachelor           2/10/11         Employed      M   22139  ...
# 3       College           1/11/11         Employed      M   49078  ...
# 4      Bachelor           1/17/11    Medical Leave      F   23675  ...
# ...         ...               ...              ...    ...     ...  ...
# 10905  Bachelor           1/19/11       Unemployed      F       0  ...
# 10906   College            1/6/11         Employed      F   61146  ...
# 10907  Bachelor            2/6/11         Employed      F   39837  ...
# 10908   College           2/13/11         Employed      F   64195  ...
# 10909  Bachelor            1/8/11       Unemployed      M       0  ...
#
#       number of open complaints number of policies     policy type  \
# 0                           0.0                  9  Corporate Auto
# 1                           0.0                  1   Personal Auto
# 2                           0.0                  2   Personal Auto
# 3                           0.0                  2  Corporate Auto
# 4                           NaN                  7   Personal Auto
# ...                         ...                ...             ...
# 10905                       NaN                  7   Personal Auto
# 10906                       0.0                  6   Personal Auto
# 10907                       0.0                  2  Corporate Auto
# 10908                       4.0                  6   Personal Auto
# 10909                       0.0                  3   Personal Auto
#
#              policy  renew offer type  sales channel  total claim amount  \
# 0      Corporate L3            Offer3          Agent          292.800000
# 1       Personal L3            Offer4    Call Center          744.924331
# 2       Personal L3            Offer3    Call Center          480.000000
# 3      Corporate L3            Offer2         Branch          484.013411
# 4       Personal L2            Offer1         Branch          707.925645
# ...             ...               ...            ...                 ...
# 10905   Personal L1            Offer3            Web         1214.400000
# 10906   Personal L3            Offer2         Branch          273.018929
# 10907  Corporate L3            Offer1            Web          381.306996
# 10908   Personal L1            Offer1         Branch          618.288849
# 10909   Personal L1            Offer4            Web         1021.719397
#
#        vehicle class vehicle size vehicle type
# 0      Four-Door Car      Medsize          NaN
# 1      Four-Door Car      Medsize          NaN
# 2                SUV      Medsize            A
# 3      Four-Door Car      Medsize            A
# 4      Four-Door Car      Medsize          NaN
# ...              ...          ...          ...
# 10905     Luxury Car      Medsize            A
# 10906  Four-Door Car      Medsize            A
# 10907     Luxury SUV      Medsize          NaN
# 10908            SUV      Medsize            A
# 10909            SUV      Medsize          NaN
#
# [10910 rows x 25 columns]

# %%
file1.customer.nunique()
# Out:
# 9134

# %%
file1= file1.drop_duplicates(subset=None, keep="first", inplace=False)

# %%
file1.customer.nunique()
# Out:
# 9134

# %%
file1 = file1.set_index("customer")

# %%
file1
# Out:
#                state  customer lifetime value response  coverage education  \
# customer
# DK49336      Arizona              4809.216960       No     Basic   College
# KX64629   California              2228.525238       No     Basic   College
# LZ68649   Washington             14947.917300       No     Basic  Bachelor
# XL78013       Oregon             22332.439460      Yes  Extended   College
# QA50777       Oregon              9025.067525       No   Premium  Bachelor
# ...              ...                      ...      ...       ...       ...
# FE99816       Nevada             15563.369440       No   Premium  Bachelor
# KX53892       Oregon              5259.444853       No     Basic   College
# TL39050      Arizona             23893.304100       No  Extended  Bachelor
# WA60547   California             11971.977650       No   Premium   College
# IV32877          NaN              6857.519928      NaN     Basic  Bachelor
#
#          effective to date employmentstatus gender  income location code  ...  \
# customer                                                                  ...
# DK49336            2/18/11         Employed      M   48029      Suburban  ...
# KX64629            1/18/11       Unemployed      F       0      Suburban  ...
# LZ68649            2/10/11         Employed      M   22139      Suburban  ...
# XL78013            1/11/11         Employed      M   49078      Suburban  ...
# QA50777            1/17/11    Medical Leave      F   23675      Suburban  ...
# ...                    ...              ...    ...     ...           ...  ...
# FE99816            1/19/11       Unemployed      F       0      Suburban  ...
# KX53892             1/6/11         Employed      F   61146         Urban  ...
# TL39050             2/6/11         Employed      F   39837         Rural  ...
# WA60547            2/13/11         Employed      F   64195         Urban  ...
# IV32877             1/8/11       Unemployed      M       0      Suburban  ...
#
#          number of open complaints  number of policies     policy type  \
# customer
# DK49336                        0.0                   9  Corporate Auto
# KX64629                        0.0                   1   Personal Auto
# LZ68649                        0.0                   2   Personal Auto
# XL78013                        0.0                   2  Corporate Auto
# QA50777                        NaN                   7   Personal Auto
# ...                            ...                 ...             ...
# FE99816                        NaN                   7   Personal Auto
# KX53892                        0.0                   6   Personal Auto
# TL39050                        0.0                   2  Corporate Auto
# WA60547                        4.0                   6   Personal Auto
# IV32877                        0.0                   3   Personal Auto
#
#                 policy  renew offer type  sales channel total claim amount  \
# customer
# DK49336   Corporate L3            Offer3          Agent         292.800000
# KX64629    Personal L3            Offer4    Call Center         744.924331
# LZ68649    Personal L3            Offer3    Call Center         480.000000
# XL78013   Corporate L3            Offer2         Branch         484.013411
# QA50777    Personal L2            Offer1         Branch         707.925645
# ...                ...               ...            ...                ...
# FE99816    Personal L1            Offer3            Web        1214.400000
# KX53892    Personal L3            Offer2         Branch         273.018929
# TL39050   Corporate L3            Offer1            Web         381.306996
# WA60547    Personal L1            Offer1         Branch         618.288849
# IV32877    Personal L1            Offer4            Web        1021.719397
#
#           vehicle class vehicle size vehicle type
# customer
# DK49336   Four-Door Car      Medsize          NaN
# KX64629   Four-Door Car      Medsize          NaN
# LZ68649             SUV      Medsize            A
# XL78013   Four-Door Car      Medsize            A
# QA50777   Four-Door Car      Medsize          NaN
# ...                 ...          ...          ...
# FE99816      Luxury Car      Medsize            A
# KX53892   Four-Door Car      Medsize            A
# TL39050      Luxury SUV      Medsize          NaN
# WA60547             SUV      Medsize            A
# IV32877             SUV      Medsize          NaN
#
# [10873 rows x 24 columns]

# %%
file1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10873 entries, DK49336 to IV32877
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   state                          10259 non-null  object
#  1   customer lifetime value        10873 non-null  float64
#  2   response                       10259 non-null  object
#  3   coverage                       10873 non-null  object
#  4   education                      10873 non-null  object
#  5   effective to date              10873 non-null  object
#  6   employmentstatus               10873 non-null  object
#  7   gender                         10873 non-null  object
#  8   income                         10873 non-null  int64
#  9   location code                  10873 non-null  object
#  10  marital status                 10873 non-null  object
#  11  monthly premium auto           10873 non-null  int64
#  12  months since last claim        10250 non-null  float64
#  13  months since policy inception  10873 non-null  int64
#  14  number of open complaints      10250 non-null  float64
#  15  number of policies             10873 non-null  int64
#  16  policy type                    10873 non-null  object
#  17  policy                         10873 non-null  object
#  18  renew offer type               10873 non-null  object
#  19  sales channel                  10873 non-null  object
#  20  total claim amount             10873 non-null  float64
#  21  vehicle class                  10265 non-null  object
#  22  vehicle size                   10265 non-null  object
#  23  vehicle type                   5408 non-null   object
# dtypes: float64(4), int64(4), object(16)
# memory usage: 2.1+ MB

# %%
file1.state.unique()
# Out:
# array(['Arizona', 'California', 'Washington', 'Oregon', nan, 'Nevada'],
#       dtype=object)

# %%
file1.gender.unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
file1.isna().sum()
# Out:
# state                             614
# customer lifetime value             0
# response                          614
# coverage                            0
# education                           0
# effective to date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location code                       0
# marital status                      0
# monthly premium auto                0
# months since last claim           623
# months since policy inception       0
# number of open complaints         623
# number of policies                  0
# policy type                         0
# policy                              0
# renew offer type                    0
# sales channel                       0
# total claim amount                  0
# vehicle class                     608
# vehicle size                      608
# vehicle type                     5465
# dtype: int64

# %%
file1 = file1.dropna()

# %%
file1
# Out:
#                state  customer lifetime value response  coverage  \
# customer
# LZ68649   Washington             14947.917300       No     Basic
# XL78013       Oregon             22332.439460      Yes  Extended
# HG93801      Arizona              5154.764074       No  Extended
# KR82385   California              5454.587929       No     Basic
# FH51383   California              5326.677654       No     Basic
# ...              ...                      ...      ...       ...
# PP30874   California              3579.023825       No  Extended
# SU71163      Arizona              2771.663013       No     Basic
# QI63521       Nevada             19228.463620       No     Basic
# KX53892       Oregon              5259.444853       No     Basic
# WA60547   California             11971.977650       No   Premium
#
#                      education effective to date employmentstatus gender  \
# customer
# LZ68649               Bachelor           2/10/11         Employed      M
# XL78013                College           1/11/11         Employed      M
# HG93801   High School or Below            1/2/11         Employed      M
# KR82385                 Master           1/26/11         Employed      M
# FH51383   High School or Below            2/7/11         Employed      F
# ...                        ...               ...              ...    ...
# PP30874   High School or Below           1/24/11         Employed      F
# SU71163                College            1/7/11         Employed      M
# QI63521   High School or Below           2/24/11       Unemployed      M
# KX53892                College            1/6/11         Employed      F
# WA60547                College           2/13/11         Employed      F
#
#           income location code  ... number of open complaints  \
# customer                        ...
# LZ68649    22139      Suburban  ...                       0.0
# XL78013    49078      Suburban  ...                       0.0
# HG93801    82730         Urban  ...                       0.0
# KR82385    66334      Suburban  ...                       0.0
# FH51383    76717         Urban  ...                       0.0
# ...          ...           ...  ...                       ...
# PP30874    28304      Suburban  ...                       2.0
# SU71163    59855      Suburban  ...                       4.0
# QI63521        0      Suburban  ...                       0.0
# KX53892    61146         Urban  ...                       0.0
# WA60547    64195         Urban  ...                       4.0
#
#           number of policies     policy type        policy  renew offer type  \
# customer
# LZ68649                    2   Personal Auto   Personal L3            Offer3
# XL78013                    2  Corporate Auto  Corporate L3            Offer2
# HG93801                    1  Corporate Auto  Corporate L3            Offer2
# KR82385                    4   Personal Auto   Personal L3            Offer4
# FH51383                    6   Personal Auto   Personal L3            Offer4
# ...                      ...             ...           ...               ...
# PP30874                    1   Personal Auto   Personal L2            Offer2
# SU71163                    1   Personal Auto   Personal L2            Offer2
# QI63521                    2   Personal Auto   Personal L2            Offer1
# KX53892                    6   Personal Auto   Personal L3            Offer2
# WA60547                    6   Personal Auto   Personal L1            Offer1
#
#           sales channel total claim amount  vehicle class vehicle size  \
# customer
# LZ68649     Call Center         480.000000            SUV      Medsize
# XL78013          Branch         484.013411  Four-Door Car      Medsize
# HG93801          Branch         442.521087            SUV        Large
# KR82385     Call Center         331.200000   Two-Door Car      Medsize
# FH51383     Call Center         300.528579   Two-Door Car        Large
# ...                 ...                ...            ...          ...
# PP30874           Agent         655.200000  Four-Door Car      Medsize
# SU71163          Branch         355.200000   Two-Door Car      Medsize
# QI63521          Branch         897.600000     Luxury SUV      Medsize
# KX53892          Branch         273.018929  Four-Door Car      Medsize
# WA60547          Branch         618.288849            SUV      Medsize
#
#          vehicle type
# customer
# LZ68649             A
# XL78013             A
# HG93801             A
# KR82385             A
# FH51383             A
# ...               ...
# PP30874             A
# SU71163             A
# QI63521             A
# KX53892             A
# WA60547             A
#
# [4543 rows x 24 columns]

# %%
file1.isna().sum()
# Out:
# state                            0
# customer lifetime value          0
# response                         0
# coverage                         0
# education                        0
# effective to date                0
# employmentstatus                 0
# gender                           0
# income                           0
# location code                    0
# marital status                   0
# monthly premium auto             0
# months since last claim          0
# months since policy inception    0
# number of open complaints        0
# number of policies               0
# policy type                      0
# policy                           0
# renew offer type                 0
# sales channel                    0
# total claim amount               0
# vehicle class                    0
# vehicle size                     0
# vehicle type                     0
# dtype: int64

# %%
file1.describe()
# Out:
#        customer lifetime value        income  monthly premium auto  \
# count              4543.000000   4543.000000           4543.000000
# mean               8033.714059  37453.033238             93.773278
# std                6959.529443  30257.399536             35.093661
# min                1904.000852      0.000000             61.000000
# 25%                4039.089902      0.000000             69.000000
# 50%                5846.520588  34455.000000             83.000000
# 75%                8936.596938  61560.000000            110.000000
# max               83325.381190  99961.000000            298.000000
#
#        months since last claim  months since policy inception  \
# count              4543.000000                    4543.000000
# mean                 15.111820                      48.153863
# std                  10.157925                      28.146904
# min                   0.000000                       0.000000
# 25%                   6.000000                      24.000000
# 50%                  14.000000                      47.000000
# 75%                  23.000000                      72.000000
# max                  35.000000                      99.000000
#
#        number of open complaints  number of policies  total claim amount
# count                4543.000000         4543.000000         4543.000000
# mean                    0.386309            2.980189          436.477525
# std                     0.907553            2.390362          295.026990
# min                     0.000000            1.000000            0.099007
# 25%                     0.000000            1.000000          265.686145
# 50%                     0.000000            2.000000          384.000000
# 75%                     0.000000            4.000000          552.000000
# max                     5.000000            9.000000         2893.239678

# %%
file1_numerical = file1.select_dtypes("number")
file1_numerical
# Out:
#           customer lifetime value  income  monthly premium auto  \
# customer
# LZ68649              14947.917300   22139                   100
# XL78013              22332.439460   49078                    97
# HG93801               5154.764074   82730                   127
# KR82385               5454.587929   66334                    69
# FH51383               5326.677654   76717                    66
# ...                           ...     ...                   ...
# PP30874               3579.023825   28304                    91
# SU71163               2771.663013   59855                    74
# QI63521              19228.463620       0                   187
# KX53892               5259.444853   61146                    65
# WA60547              11971.977650   64195                   158
#
#           months since last claim  months since policy inception  \
# customer
# LZ68649                      34.0                             31
# XL78013                      10.0                              3
# HG93801                      13.0                             31
# KR82385                      25.0                             25
# FH51383                      26.0                             10
# ...                           ...                            ...
# PP30874                      10.0                             30
# SU71163                      30.0                             82
# QI63521                      14.0                             32
# KX53892                       7.0                             68
# WA60547                       0.0                             27
#
#           number of open complaints  number of policies  total claim amount
# customer
# LZ68649                         0.0                   2          480.000000
# XL78013                         0.0                   2          484.013411
# HG93801                         0.0                   1          442.521087
# KR82385                         0.0                   4          331.200000
# FH51383                         0.0                   6          300.528579
# ...                             ...                 ...                 ...
# PP30874                         2.0                   1          655.200000
# SU71163                         4.0                   1          355.200000
# QI63521                         0.0                   2          897.600000
# KX53892                         0.0                   6          273.018929
# WA60547                         4.0                   6          618.288849
#
# [4543 rows x 8 columns]

# %%
file1_cat = file1.select_dtypes("object")
file1_cat
# Out:
#                state response  coverage             education  \
# customer
# LZ68649   Washington       No     Basic              Bachelor
# XL78013       Oregon      Yes  Extended               College
# HG93801      Arizona       No  Extended  High School or Below
# KR82385   California       No     Basic                Master
# FH51383   California       No     Basic  High School or Below
# ...              ...      ...       ...                   ...
# PP30874   California       No  Extended  High School or Below
# SU71163      Arizona       No     Basic               College
# QI63521       Nevada       No     Basic  High School or Below
# KX53892       Oregon       No     Basic               College
# WA60547   California       No   Premium               College
#
#          effective to date employmentstatus gender location code  \
# customer
# LZ68649            2/10/11         Employed      M      Suburban
# XL78013            1/11/11         Employed      M      Suburban
# HG93801             1/2/11         Employed      M         Urban
# KR82385            1/26/11         Employed      M      Suburban
# FH51383             2/7/11         Employed      F         Urban
# ...                    ...              ...    ...           ...
# PP30874            1/24/11         Employed      F      Suburban
# SU71163             1/7/11         Employed      M      Suburban
# QI63521            2/24/11       Unemployed      M      Suburban
# KX53892             1/6/11         Employed      F         Urban
# WA60547            2/13/11         Employed      F         Urban
#
#          marital status     policy type        policy renew offer type  \
# customer
# LZ68649          Single   Personal Auto   Personal L3           Offer3
# XL78013          Single  Corporate Auto  Corporate L3           Offer2
# HG93801         Married  Corporate Auto  Corporate L3           Offer2
# KR82385          Single   Personal Auto   Personal L3           Offer4
# FH51383         Married   Personal Auto   Personal L3           Offer4
# ...                 ...             ...           ...              ...
# PP30874         Married   Personal Auto   Personal L2           Offer2
# SU71163         Married   Personal Auto   Personal L2           Offer2
# QI63521          Single   Personal Auto   Personal L2           Offer1
# KX53892         Married   Personal Auto   Personal L3           Offer2
# WA60547        Divorced   Personal Auto   Personal L1           Offer1
#
#          sales channel  vehicle class vehicle size vehicle type
# customer
# LZ68649    Call Center            SUV      Medsize            A
# XL78013         Branch  Four-Door Car      Medsize            A
# HG93801         Branch            SUV        Large            A
# KR82385    Call Center   Two-Door Car      Medsize            A
# FH51383    Call Center   Two-Door Car        Large            A
# ...                ...            ...          ...          ...
# PP30874          Agent  Four-Door Car      Medsize            A
# SU71163         Branch   Two-Door Car      Medsize            A
# QI63521         Branch     Luxury SUV      Medsize            A
# KX53892         Branch  Four-Door Car      Medsize            A
# WA60547         Branch            SUV      Medsize            A
#
# [4543 rows x 16 columns]

# %%
for column in file1_numerical.columns:
    sns.displot(file1[column])
plt.show()

# %%
file1.corr().apply(lambda x: round(x,2))
# Out:
#                                customer lifetime value  income  \
# customer lifetime value                           1.00    0.02
# income                                            0.02    1.00
# monthly premium auto                              0.41   -0.01
# months since last claim                           0.03   -0.01
# months since policy inception                     0.02   -0.01
# number of open complaints                        -0.03    0.00
# number of policies                                0.02   -0.01
# total claim amount                                0.23   -0.36
#
#                                monthly premium auto  months since last claim  \
# customer lifetime value                        0.41                     0.03
# income                                        -0.01                    -0.01
# monthly premium auto                           1.00                     0.00
# months since last claim                        0.00                     1.00
# months since policy inception                  0.03                    -0.04
# number of open complaints                     -0.00                    -0.00
# number of policies                            -0.03                     0.00
# total claim amount                             0.63                    -0.01
#
#                                months since policy inception  \
# customer lifetime value                                 0.02
# income                                                 -0.01
# monthly premium auto                                    0.03
# months since last claim                                -0.04
# months since policy inception                           1.00
# number of open complaints                              -0.00
# number of policies                                     -0.01
# total claim amount                                      0.01
#
#                                number of open complaints  number of policies  \
# customer lifetime value                            -0.03                0.02
# income                                              0.00               -0.01
# monthly premium auto                               -0.00               -0.03
# months since last claim                            -0.00                0.00
# months since policy inception                      -0.00               -0.01
# number of open complaints                           1.00                0.01
# number of policies                                  0.01                1.00
# total claim amount                                 -0.00                0.00
#
#                                total claim amount
# customer lifetime value                      0.23
# income                                      -0.36
# monthly premium auto                         0.63
# months since last claim                     -0.01
# months since policy inception                0.01
# number of open complaints                   -0.00
# number of policies                           0.00
# total claim amount                           1.00

# %%
mask = np.zeros_like(file1.corr())
mask[np.triu_indices_from(mask)]=True
fig, ax = plt.subplots(figsize=(10,8))
ax =sns.heatmap(file1.corr(), mask=mask, annot=True)
plt.show()
